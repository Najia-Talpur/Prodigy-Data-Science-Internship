# %% [markdown]
# # Histogram of Population of Countries from 1960 to 2022

# %% [markdown]
# #### This code utilizes a dataset from The World Bank, containing comprehensive population details for each country from 1960 to 2023. We aim to create a histogram to visualize the distribution of a categorical or continuous variable, such as age groups or gender distribution within a population.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Task1_dataset.csv")
data.head()
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54608.0      55811.0
# 1  Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                  Afghanistan          AFG    8622466.0    8790140.0
# 3   Africa Western and Central          AFW   97256290.0   99314028.0
# 4                       Angola          AGO    5357195.0    5441333.0
#
#           1962         1963         1964         1965         1966  \
# 0      56682.0      57475.0      58178.0      58782.0      59291.0
# 1  137835590.0  141630546.0  145605995.0  149742351.0  153955516.0
# 2    8969047.0    9157465.0    9355514.0    9565147.0    9783147.0
# 3  101445032.0  103667517.0  105959979.0  108336203.0  110798486.0
# 4    5521400.0    5599827.0    5673199.0    5736582.0    5787044.0
#
#           1967  ...         2013         2014         2015         2016  \
# ...

# %%
data.drop(columns=['Country Code'], inplace=True)

# %%
data.head()
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
#           1968  ...         2013         2014         2015         2016  \
# ...

# %%
countries = data['Country Name']

# %%
countries.head()
# Out:
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# Name: Country Name, dtype: object

# %%
print(data.columns)
# Out:
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022'],
#       dtype='object')

# %%
data.drop(columns=['Country Name'], inplace=True)

# %%
years_data = data
years_data.head()
# Out:
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965         1966         1967         1968         1969  ...  \
# 0      58782.0      59291.0      59522.0      59471.0      59330.0  ...
# 1  149742351.0  153955516.0  158313235.0  162875171.0  167596160.0  ...
# 2    9565147.0    9783147.0   10010030.0   10247780.0   10494489.0  ...
# 3  108336203.0  110798486.0  113319950.0  115921723.0  118615741.0  ...
# 4    5736582.0    5787044.0    5827503.0    5868203.0    5928386.0  ...
#
#           2013         2014         2015         2016         2017  \
# ...

# %%
nan_values_countries = countries.isna().sum()
nan_values_countries
# Out:
# 0

# %%
nan_values_countries = countries

# %%
nan_values = data.isna().sum()
nan_values
# Out:
# 1960    2
# 1961    2
# 1962    2
# 1963    2
# 1964    2
#        ..
# 2018    1
# 2019    1
# 2020    1
# 2021    1
# 2022    1
# Length: 63, dtype: int64

# %%
column_means = data.mean()
data_filled = data.fillna(column_means)

# %%
nan_values = data_filled.isna().sum()
nan_values
# Out:
# 1960    0
# 1961    0
# 1962    0
# 1963    0
# 1964    0
#        ..
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# 2022    0
# Length: 63, dtype: int64

# %%
nan_values = data

# %%
# Generating random colors for each histogram
num_countries = len(countries)
colors = np.random.rand(num_countries, 3)  # Generating random RGB colors

# Plotting histograms for each country's population over the years in 3 graphs per row
num_plots = len(countries)
plots_per_row = 3
num_rows = -(-num_plots // plots_per_row)  # Ceiling division to determine number of rows

fig, axs = plt.subplots(num_rows, plots_per_row, figsize=(15, 5 * num_rows))  # Adjust figure size here
fig.subplots_adjust(hspace=0.5)  # Adjust horizontal space between subplots

for i, country in enumerate(countries):
    row = i // plots_per_row
    col = i % plots_per_row
    ax = axs[row, col] if num_rows > 1 else axs[col]  # Handling single row case
    
    ax.hist(years_data.iloc[i].dropna(), bins=20, color=colors[i])  # Assigning random color
    ax.set_xlabel('Year')
    ax.set_ylabel('Population')
    ax.set_title(f'Population Distribution for {country}')

# Hide empty subplots if any
for i in range(num_plots, num_rows * plots_per_row):
    row = i // plots_per_row
    col = i % plots_per_row
    axs[row, col].axis('off')

plt.show()
